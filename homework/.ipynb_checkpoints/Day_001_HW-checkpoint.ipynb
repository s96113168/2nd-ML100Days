# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """

# %%
def mean_absolute_error(y, y_hat):
    """
    新增Function
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)

# %%
作業1：

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

LANL Earthquake Prediction URL:https://www.kaggle.com/c/LANL-Earthquake-Prediction/overview

1. 你選的這組資料為何重要

A:這是一個地震預測的競賽，如果可以提高地震預測成功的機率可以大大提升大地震發生的生存機會。

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

A:這篇競賽的資料只說是由著名於研究地震物理學的裝置偵測而來。

3. 蒐集而來的資料型態為何

A:
acoustic_data - 地震信號[int16]
time_to_failure  - 直到下一次地震的時間（以秒為單位）[float64]
seg_id - 應對其進行預測的測試段ID（每個段一個預測）

4. 這組資料想解決的問題如何評估

A:資料會給出目前的地震信號 並給出下一次地震的時間，在其中找出規律性以預測出下一次地震的時間與地震大小
# Out:
#   File "<ipython-input-41-b40267ac187f>", line 1
#     作業1：
#        ^
# SyntaxError: invalid character in identifier

# %%
作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

如果要提升業績的話要從宣傳開始讓載客數量增加，因為如果是自由載客車隊代表無法在路邊隨停隨載，只可以透過平台(APP,WEB)來吸引載客增加載客率
所以核心問題應該是要研究如何有效投放廣告來吸引載客以提升此服務的使用率，以及如何留住客戶不讓客戶流失

2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

從已現有的平台取得瀏覽資料、停留時間、GPS位置(APP端)

3. 蒐集而來的資料型態為何

age 使用者年齡層
logintime 登入時間(一個禮拜登入次數、容易於禮拜幾登入)
staytime 停留於網站orAPP時間
GPS位置

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
依照使用者的年齡層定義不同的使用頻率，再以登入次數加以輔助判斷該使用者對於此服務的需求程度
再按照該使用者的使用習慣來發送折扣的頻率 增加顧客對於此服務的好感與需求程度
GPS可以了解哪些區域比較喜歡此服務、哪些區域比較不習慣使用此服務，再依照這個區域使用程度來投放廣告吸引使用者下載平台

# %%
作業3：

請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式

資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔) 

(請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)
